# %%
import pandas as pd 
df = pd.read_csv('../data/processed/credit_risk_dataset.csv')
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          21           9600                   OWN                5.0
# 1          25           9600              MORTGAGE                1.0
# 2          23          65500                  RENT                4.0
# 3          24          54400                  RENT                8.0
# 4          21           9900                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0   EDUCATION          B       1000          11.14            0
# 1     MEDICAL          C       5500          12.87            1
# 2     MEDICAL          C      35000          15.23            1
# 3     MEDICAL          C      35000          14.27            1
# 4     VENTURE          A       2500           7.14            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.10                         N                           2
# 1                 0.57                         N                           3
# 2                 0.53                         N                           2
# 3                 0.55                         Y                           4
# 4                 0.25                         N                           2

# %%
df['loan_status'] = df['loan_status'].replace({0:'non_defualt', 1:'defualt'})
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = df[i].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28632 entries, 0 to 28631
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  28632 non-null  int64
#  1   person_income               28632 non-null  int64
#  2   person_home_ownership       28632 non-null  category
#  3   person_emp_length           28632 non-null  float64
#  4   loan_intent                 28632 non-null  category
#  5   loan_grade                  28632 non-null  category
#  6   loan_amnt                   28632 non-null  int64
#  7   loan_int_rate               28632 non-null  float64
#  8   loan_status                 28632 non-null  category
#  9   loan_percent_income         28632 non-null  float64
#  10  cb_person_default_on_file   28632 non-null  category
#  11  cb_person_cred_hist_length  28632 non-null  int64
# dtypes: category(5), float64(3), int64(4)
# memory usage: 1.7 MB

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          21           9600                   OWN                5.0
# 1          25           9600              MORTGAGE                1.0
# 2          23          65500                  RENT                4.0
# 3          24          54400                  RENT                8.0
# 4          21           9900                   OWN                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0   EDUCATION          B       1000          11.14  non_defualt
# 1     MEDICAL          C       5500          12.87      defualt
# 2     MEDICAL          C      35000          15.23      defualt
# 3     MEDICAL          C      35000          14.27      defualt
# 4     VENTURE          A       2500           7.14      defualt
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.10                         N                           2
# 1                 0.57                         N                           3
# 2                 0.53                         N                           2
# 3                 0.55                         Y                           4
# 4                 0.25                         N                           2

# %% [markdown]
# ### both ANOVA and Eta Squared (η²) are sensitive to outliers,

# %%
def remove_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    return df[(df[col] >= lower) & (df[col] <= upper)]

# %%
clean_df = df.copy()
# num_cols = [
#     'person_age', 'person_income', 'person_emp_length',
#     'loan_amnt', 'loan_int_rate',
#     'loan_percent_income', 'cb_person_cred_hist_length'
# ]
# for col in num_cols:
#     clean_df = remove_outliers_iqr(clean_df, col)
#     # print(len(clean_df))

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

fig, axes = plt.subplots(len(clean_df.columns)//4, 5, figsize=(15, 6))
axes = axes.flatten()
for i, col in enumerate(clean_df.columns):
    # if clean_df[col].dtype != 'category':
    sns.histplot(clean_df[col], ax=axes[i])
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")
    
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])
    
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

fig, axes = plt.subplots(len(df.columns)//4, 5, figsize=(15, 6))
axes = axes.flatten()
for i, col in enumerate(df.columns):
    # if df[col].dtype != 'category':
    sns.histplot(df[col], ax=axes[i])
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Frequency")
    
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])
    
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(len(clean_df.columns)//4, 5, figsize=(15, 6))
axes = axes.flatten()
for i, col in enumerate(clean_df.columns):
    sns.boxplot(clean_df[col], ax=axes[i])
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Value")

for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

num_cols = [
    'person_age', 'person_income', 'person_emp_length',
    'loan_amnt', 'loan_int_rate',
    'loan_percent_income', 'cb_person_cred_hist_length'
]

cat_cols = [
    'person_home_ownership',
    'loan_intent',
    'loan_grade',
    'loan_status',
    'cb_person_default_on_file'
]

results = []

for num in num_cols:
    for cat in cat_cols:
        model = ols(f'{num} ~ C({cat})', data=clean_df).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        eta_sq = anova_table['sum_sq'][f'C({cat})'] / anova_table['sum_sq'].sum()
        
        p_value = anova_table['PR(>F)'][f'C({cat})']

        results.append({
            'Numeric_Var': num,
            'Categorical_Var': cat,
            'Eta_Squared': eta_sq,
            'p_value': p_value
        })

eta_df = pd.DataFrame(results)
eta_df.sort_values(by='Eta_Squared', ascending=False)
# Out:
#                    Numeric_Var            Categorical_Var  Eta_Squared  \
# 22               loan_int_rate                 loan_grade     0.900750
# 24               loan_int_rate  cb_person_default_on_file     0.250738
# 23               loan_int_rate                loan_status     0.113936
# 28         loan_percent_income                loan_status     0.102185
# 5                person_income      person_home_ownership     0.099414
# 8                person_income                loan_status     0.064182
# 10           person_emp_length      person_home_ownership     0.062444
# 20               loan_int_rate      person_home_ownership     0.025042
# 1                   person_age                loan_intent     0.020820
# 25         loan_percent_income      person_home_ownership     0.020801
# 27         loan_percent_income                 loan_grade     0.015200
# 15                   loan_amnt      person_home_ownership     0.011904
# 17                   loan_amnt                 loan_grade     0.011897
# 31  cb_person_cred_hist_length                loan_intent     0.010583
# 6                person_income                loan_intent     0.009947
# 13           person_emp_length                loan_status     0.008471
# 7                person_income                 loan_grade     0.006899
# 12           person_emp_length                 loan_grade     0.005487
# 18                   loan_amnt                loan_status     0.003442
# 16                   loan_amnt                loan_intent     0.001928
# 11           person_emp_length                loan_intent     0.001329
# 0                   person_age      person_home_ownership     0.001207
# 14           person_emp_length  cb_person_default_on_file     0.001202
# 29         loan_percent_income  cb_person_default_on_file     0.000943
# 9                person_income  cb_person_default_on_file     0.000905
# 3                   person_age                loan_status     0.000730
# 30  cb_person_cred_hist_length      person_home_ownership     0.000652
# 26         loan_percent_income                loan_intent     0.000619
# 32  cb_person_cred_hist_length                 loan_grade     0.000505
# 2                   person_age                 loan_grade     0.000485
# 21               loan_int_rate                loan_intent     0.000434
# 19                   loan_amnt  cb_person_default_on_file     0.000423
# 33  cb_person_cred_hist_length                loan_status     0.000375
# 4                   person_age  cb_person_default_on_file     0.000227
# 34  cb_person_cred_hist_length  cb_person_default_on_file     0.000165
#
#           p_value
# 22   0.000000e+00
# 24   0.000000e+00
# 23   0.000000e+00
# 28   0.000000e+00
# 5    0.000000e+00
# 8    0.000000e+00
# 10  2.865581e-322
# 20  1.694212e-126
# 1   1.128243e-102
# 25  8.596212e-105
# 27   2.946462e-73
# 15   1.349757e-59
# 17   1.063502e-56
# 31   5.180399e-51
# 6    7.869522e-48
# 13   1.352029e-44
# 7    6.822821e-32
# 12   5.669039e-25
# 18   4.694089e-19
# 16   1.810248e-08
# 11   1.087227e-05
# 0    3.880498e-06
# 14   1.380537e-07
# 29   3.083626e-06
# 9    4.880253e-06
# 3    4.038275e-05
# 30   1.778389e-03
# 26   1.385014e-02
# 32   7.043941e-02
# 2    8.247566e-02
# 21   7.474100e-02
# 19   1.778948e-03
# 33   3.272252e-03
# 4    2.200878e-02
# 34   5.130723e-02

# %% [markdown]
# #### Example: η² = 0.21 → loan_grade explains 21% of variance in loan_amnt
# Anova measures how much variance in a numerical variable is explained by a categorical variable
# | Condition | Interpretation                |
# | --------- | ----------------------------- |
# | p < 0.05  | Significant relationship      |
# | p ≥ 0.05  | Not statistically significant |

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.boxplot(x='loan_grade', y='loan_int_rate', data=df)
plt.title('Loan Amount by Loan Grade')
plt.xlabel('Loan Grade')
plt.ylabel('Loan Amount')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.violinplot(x='loan_grade', y='loan_int_rate', data=df, inner='quartile')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.pointplot(x='loan_grade', y='loan_int_rate', data=df, errorbar='ci')
plt.title('Mean Loan Amount by Loan Grade')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

num_cols = [
    'person_age', 'person_income', 'person_emp_length',
    'loan_amnt', 'loan_int_rate',
    'loan_percent_income', 'cb_person_cred_hist_length'
]

cat_cols = [
    'person_home_ownership',
    'loan_intent',
    'loan_grade',
    'loan_status',
    'cb_person_default_on_file'
]

# %%
# fig, axes = plt.subplots(
#     nrows=len(num_cols),
#     ncols=len(cat_cols),
#     figsize=(4 * len(cat_cols), 3 * len(num_cols)),
#     constrained_layout=True
# )

# for i, num in enumerate(num_cols):
#     for j, cat in enumerate(cat_cols):
#         sns.violinplot(
#             x=cat,
#             y=num,
#             data=df,
#             ax=axes[i, j],
#             inner='quartile',
#             cut=0
#         )
#         axes[i, j].set_title(f'{num} vs {cat}', fontsize=9)
#         axes[i, j].tick_params(axis='x', rotation=45)

# plt.show()

# %%
for num in num_cols:
    fig, axes = plt.subplots(1, len(cat_cols), figsize=(18,4))
    for j, cat in enumerate(cat_cols):
        sns.boxplot(x=cat, y=num, data=df, ax=axes[j])
        axes[j].set_title(f'{num} vs {cat}')
        axes[j].tick_params(axis='x', rotation=45)
    plt.show()

# %%
eta_pivot = eta_df.pivot(
    index='Numeric_Var',
    columns='Categorical_Var',
    values='Eta_Squared'
)

plt.figure(figsize=(10,6))
sns.heatmap(eta_pivot, annot=True, cmap='Blues')
plt.title('Eta Squared Heatmap (Category → Numeric)')
plt.show()
